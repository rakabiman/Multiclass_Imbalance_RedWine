# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from mlxtend.classifier import StackingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, balanced_accuracy_score
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, classification_report, precision_recall_curve
from sklearn.model_selection import train_test_split
from imblearn.metrics import geometric_mean_score, sensitivity_score, specificity_score
from xgboost import XGBClassifier
from shaphypetune import BoostRFE
from sklearn.base import BaseEstimator
from sklearn.utils.metaestimators import if_delegate_has_method

import torch
import re, pickle, random, os
import warnings
warnings.filterwarnings('ignore')

from collections import Counter

# %%
def seed_everything(seed=1234):
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

RANDOM_STATE = 42
seed_everything(seed=RANDOM_STATE)

# %%
df = pd.read_csv("redwine.csv",delimiter=';')
df.shape
# Out:
# (1599, 12)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# # Train and Test Split

# %%
x = df.drop(['quality'], axis=1)
y = df['quality']

X_train,X_test,y_train,y_test=train_test_split(x, y, train_size=0.8, stratify = y, random_state=100)

# %%
y_train.shape, y_test.shape
# Out:
# ((1279,), (320,))

# %%
y_train.value_counts()/len(y_train)
# Out:
# 5    0.426114
# 6    0.398749
# 7    0.124316
# 4    0.032838
# 8    0.011728
# 3    0.006255
# Name: quality, dtype: float64

# %%
y_test.value_counts()/len(y_test)
# Out:
# 5    0.425000
# 6    0.400000
# 7    0.125000
# 4    0.034375
# 8    0.009375
# 3    0.006250
# Name: quality, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
Scaler_X = StandardScaler()
X_train = Scaler_X.fit_transform(X_train)
X_test = Scaler_X.transform(X_test)

# %% [markdown]
# # Model Building

# %%
model = list()
precision = list()
recall = list()
F1score = list()
AUCROC = list()
balanced_acc = list()
GMean = list()
sensi = list()
speci = list()

# %%
def test_eval(clf_model, X_test, y_test, algo=None):

    y_prob=clf_model.predict_proba(X_test)
    y_pred=clf_model.predict(X_test)

    print('Confusion Matrix')
    print('='*60)
    print(confusion_matrix(y_test,y_pred),"\n")
    print('Classification Report')
    print('='*60)
    print(classification_report(y_test,y_pred),"\n")
    print('='*60)
    print('AUC-ROC')
    print(roc_auc_score(y_test, y_prob, multi_class='ovr'), "\n")
    print('Balanced Accuracy')
    print(balanced_accuracy_score(y_test, y_pred),"\n")
    print('Geometric Mean Score')
    print(geometric_mean_score(y_test, y_pred, average='macro'),"\n")
    print('Sensitivity')
    print(sensitivity_score(y_test, y_pred, average='macro'),"\n")
    print('Specificity')
    print(specificity_score(y_test, y_pred, average='macro'))
          
    model.append(algo)
    precision.append(precision_score(y_test,y_pred, average='macro'))
    recall.append(recall_score(y_test,y_pred, average='macro'))
    F1score.append(f1_score(y_test,y_pred, average='macro'))
    AUCROC.append(roc_auc_score(y_test, y_prob, multi_class='ovr', average='macro'))
    balanced_acc.append(balanced_accuracy_score(y_test, y_pred))
    GMean.append(geometric_mean_score(y_test, y_pred, average='macro'))
    sensi.append(sensitivity_score(y_test, y_pred, average='macro'))
    speci.append(specificity_score(y_test, y_pred, average='macro'))

# %% [markdown]
# ## Model-1: Logistic Regression

# %%
clf_LR = LogisticRegression(multi_class='ovr', solver='liblinear')
clf_LR.fit(X_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
test_eval(clf_LR, X_test, y_test, 'Logistic Regression')
# Out:
# Confusion Matrix
# ============================================================
# [[  0   0   2   0   0   0]
#  [  0   0   9   1   1   0]
#  [  0   0 110  25   1   0]
#  [  0   0  48  78   2   0]
#  [  0   0   1  33   6   0]
#  [  0   0   0   0   3   0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.65      0.81      0.72       136
#            6       0.57      0.61      0.59       128
#            7       0.46      0.15      0.23        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.61       320
#    macro avg       0.28      0.26      0.26       320
# weighted avg       0.56      0.61      0.57       320
#
#
# ============================================================
# AUC-ROC
# 0.8181440947737783
#
# Balanced Accuracy
# 0.26136642156862744
#
# Geometric Mean Score
# 0.48237614379785465
#
# Sensitivity
# 0.26136642156862744
#
# Specificity
# 0.890270229468599

# %% [markdown]
# ## Model-2: Decision Tree

# %%
clf_DT = DecisionTreeClassifier()
clf_DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
test_eval(clf_DT, X_test, y_test, 'Decision Tree')
# Out:
# Confusion Matrix
# ============================================================
# [[ 0  2  0  0  0  0]
#  [ 0  2  6  2  1  0]
#  [ 0  7 97 28  4  0]
#  [ 0  7 32 72 17  0]
#  [ 0  3  6 10 20  1]
#  [ 0  0  0  3  0  0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.10      0.18      0.12        11
#            5       0.69      0.71      0.70       136
#            6       0.63      0.56      0.59       128
#            7       0.48      0.50      0.49        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.60       320
#    macro avg       0.31      0.33      0.32       320
# weighted avg       0.61      0.60      0.60       320
#
#
# ============================================================
# AUC-ROC
# 0.6126041693314006
#
# Balanced Accuracy
# 0.32625891265597146
#
# Geometric Mean Score
# 0.5415627962311462
#
# Sensitivity
# 0.32625891265597146
#
# Specificity
# 0.8989494260068298

# %% [markdown]
# ## Model-3: Gaussian NB

# %%
clf_NB = GaussianNB()
clf_NB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
test_eval(clf_NB, X_test, y_test, 'Gaussian NB')
# Out:
# Confusion Matrix
# ============================================================
# [[ 0  0  2  0  0  0]
#  [ 0  2  4  4  1  0]
#  [ 1  5 89 36  5  0]
#  [ 0  3 35 74 14  2]
#  [ 0  0  1 14 19  6]
#  [ 0  0  0  0  2  1]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.20      0.18      0.19        11
#            5       0.68      0.65      0.67       136
#            6       0.58      0.58      0.58       128
#            7       0.46      0.47      0.47        40
#            8       0.11      0.33      0.17         3
#
#     accuracy                           0.58       320
#    macro avg       0.34      0.37      0.35       320
# weighted avg       0.59      0.58      0.58       320
#
#
# ============================================================
# AUC-ROC
# 0.7025279754401752
#
# Balanced Accuracy
# 0.3704480466428996
#
# Geometric Mean Score
# 0.5751419644663356
#
# Sensitivity
# 0.3704480466428996
#
# Specificity
# 0.8929410811796378

# %% [markdown]
# ## Model-4: K-Nearest Neighbour

# %%
clf_KNN = KNeighborsClassifier()
clf_KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
test_eval(clf_KNN, X_test, y_test, 'KNN')
# Out:
# Confusion Matrix
# ============================================================
# [[ 0  0  1  1  0  0]
#  [ 0  2  5  4  0  0]
#  [ 1  1 90 43  1  0]
#  [ 0  0 56 63  8  1]
#  [ 0  0  5 16 19  0]
#  [ 0  0  0  2  1  0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.67      0.18      0.29        11
#            5       0.57      0.66      0.61       136
#            6       0.49      0.49      0.49       128
#            7       0.66      0.47      0.55        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.54       320
#    macro avg       0.40      0.30      0.32       320
# weighted avg       0.54      0.54      0.54       320
#
#
# ============================================================
# AUC-ROC
# 0.6317945795063217
#
# Balanced Accuracy
# 0.30179506461675576
#
# Geometric Mean Score
# 0.5137248634458315
#
# Sensitivity
# 0.30179506461675576
#
# Specificity
# 0.8744783008879784

# %% [markdown]
# ## MODEL-5 Support Vector Classifier

# %%
clf_SVC = SVC(probability=True)
clf_SVC.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
test_eval(clf_SVC, X_test, y_test, 'SVC')
# Out:
# Confusion Matrix
# ============================================================
# [[  0   0   2   0   0   0]
#  [  0   0   9   2   0   0]
#  [  0   0 106  29   1   0]
#  [  0   0  48  75   5   0]
#  [  0   0   2  25  13   0]
#  [  0   0   0   2   1   0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.63      0.78      0.70       136
#            6       0.56      0.59      0.57       128
#            7       0.65      0.33      0.43        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.61       320
#    macro avg       0.31      0.28      0.28       320
# weighted avg       0.58      0.61      0.58       320
#
#
# ============================================================
# AUC-ROC
# 0.8311091612733549
#
# Balanced Accuracy
# 0.28172487745098035
#
# Geometric Mean Score
# 0.5007999985652012
#
# Sensitivity
# 0.28172487745098035
#
# Specificity
# 0.8902324879227054

# %% [markdown]
# # MODEL-6 XGBoost

# %%
class BoostRFEWrap(BaseEstimator, BoostRFE):

    @if_delegate_has_method(delegate='estimator')
    def predict_proba(self, X):
        return self.predict(X, method='predict_proba')


xgb_params = {'max_depth': (5,10),
          'learning_rate': (0.001, 0.3),
          'n_estimators': (25, 200),
          'reg_alpha' : (0.1, 1),
          'reg_lambda': (0.1, 1),
          'subsample': (0.5,  0.9),
          'colsample_bytree': (0.5,1),
          'min_child_weight': (0,10),
          'gamma': (0,1)}

clf_XGB = BoostRFEWrap(XGBClassifier(), param_grid=xgb_params, importance_type='shap_importances', train_importance=False, min_features_to_select=1, step=1)

# %%
xclf = clf_XGB.fit(X_train, y_train, eval_set=[(X_test, y_test)], early_stopping_rounds=6, verbose=0)
# Out:
# 512 trials detected for ('max_depth', 'learning_rate', 'n_estimators', 'reg_alpha', 'reg_lambda', 'subsample', 'colsample_bytree', 'min_child_weight', 'gamma')
#
# trial: 0001 ### iterations: 00022 ### eval_score: 0.3125
# trial: 0002 ### iterations: 00017 ### eval_score: 0.325
# trial: 0003 ### iterations: 00034 ### eval_score: 0.34063
# trial: 0004 ### iterations: 00017 ### eval_score: 0.34063
# trial: 0005 ### iterations: 00021 ### eval_score: 0.30625
# trial: 0006 ### iterations: 00014 ### eval_score: 0.3125
# trial: 0007 ### iterations: 00026 ### eval_score: 0.325
# trial: 0008 ### iterations: 00016 ### eval_score: 0.34375
# trial: 0009 ### iterations: 00021 ### eval_score: 0.31562
# trial: 0010 ### iterations: 00014 ### eval_score: 0.31562
# trial: 0011 ### iterations: 00030 ### eval_score: 0.31562
# trial: 0012 ### iterations: 00016 ### eval_score: 0.31875
# trial: 0013 ### iterations: 00019 ### eval_score: 0.30938
# trial: 0014 ### iterations: 00016 ### eval_score: 0.3
# trial: 0015 ### iterations: 00012 ### eval_score: 0.33125
# trial: 0016 ### iterations: 00013 ### eval_score: 0.33125
# trial: 0017 ### iterations: 00023 ### eval_score: 0.32188
# trial: 0018 ### iterations: 00013 ### eval_score: 0.33437
# trial: 0019 ### iterations: 00014 ### eval_score: 0.35625
# trial: 0020 ### iterations: 00012 ### eval_score: 0.3625
# trial: 0021 ### iterations: 00015 ### eval_score: 0.31562
# trial: 0022 ### iterations: 00014 ### eval_score: 0.3
# trial: 0023 ### iterations: 00023 ### eval_score: 0.33437
# trial: 0024 ### iterations: 00013 ### eval_score: 0.35938
# trial: 0025 ### iterations: 00012 ### eval_score: 0.3
# trial: 0026 ### iterations: 00020 ### eval_score: 0.32188
# trial: 0027 ### iterations: 00024 ### eval_score: 0.30625
# trial: 0028 ### iterations: 00025 ### eval_score: 0.32812
# trial: 0029 ### iterations: 00013 ### eval_score: 0.30938
# trial: 0030 ### iterations: 00014 ### eval_score: 0.32812
# trial: 0031 ### iterations: 00012 ### eval_score: 0.33125
# trial: 0032 ### iterations: 00016 ### eval_score: 0.34063
# trial: 0033 ### iterations: 00038 ### eval_score: 0.33125
# trial: 0034 ### iterations: 00014 ### eval_score: 0.33437
# trial: 0035 ### iterations: 00028 ### eval_score: 0.34375
# trial: 0036 ### iterations: 00018 ### eval_score: 0.36562
# trial: 0037 ### iterations: 00024 ### eval_score: 0.29688
# trial: 0038 ### iterations: 00022 ### eval_score: 0.31875
# trial: 0039 ### iterations: 00033 ### eval_score: 0.33125
# trial: 0040 ### iterations: 00015 ### eval_score: 0.34063
# trial: 0041 ### iterations: 00021 ### eval_score: 0.31562
# trial: 0042 ### iterations: 00013 ### eval_score: 0.31562
# trial: 0043 ### iterations: 00022 ### eval_score: 0.32812
# trial: 0044 ### iterations: 00020 ### eval_score: 0.33437
# trial: 0045 ### iterations: 00031 ### eval_score: 0.30938
# trial: 0046 ### iterations: 00013 ### eval_score: 0.33125
# trial: 0047 ### iterations: 00020 ### eval_score: 0.33437
# trial: 0048 ### iterations: 00014 ### eval_score: 0.34063
# trial: 0049 ### iterations: 00026 ### eval_score: 0.31875
# trial: 0050 ### iterations: 00015 ### eval_score: 0.32812
# trial: 0051 ### iterations: 00037 ### eval_score: 0.32812
# trial: 0052 ### iterations: 00022 ### eval_score: 0.35625
# trial: 0053 ### iterations: 00024 ### eval_score: 0.3125
# trial: 0054 ### iterations: 00019 ### eval_score: 0.34687
# trial: 0055 ### iterations: 00019 ### eval_score: 0.35625
# trial: 0056 ### iterations: 00015 ### eval_score: 0.35313
# trial: 0057 ### iterations: 00011 ### eval_score: 0.30938
# trial: 0058 ### iterations: 00010 ### eval_score: 0.3375
# trial: 0059 ### iterations: 00037 ### eval_score: 0.31562
# trial: 0060 ### iterations: 00024 ### eval_score: 0.34063
# trial: 0061 ### iterations: 00015 ### eval_score: 0.30312
# trial: 0062 ### iterations: 00019 ### eval_score: 0.32188
# trial: 0063 ### iterations: 00013 ### eval_score: 0.325
# trial: 0064 ### iterations: 00020 ### eval_score: 0.3375
# trial: 0065 ### iterations: 00022 ### eval_score: 0.3125
# trial: 0066 ### iterations: 00017 ### eval_score: 0.325
# trial: 0067 ### iterations: 00021 ### eval_score: 0.35313
# trial: 0068 ### iterations: 00017 ### eval_score: 0.34063
# trial: 0069 ### iterations: 00021 ### eval_score: 0.30625
# trial: 0070 ### iterations: 00014 ### eval_score: 0.3125
# trial: 0071 ### iterations: 00024 ### eval_score: 0.32812
# trial: 0072 ### iterations: 00016 ### eval_score: 0.34375
# trial: 0073 ### iterations: 00021 ### eval_score: 0.31562
# trial: 0074 ### iterations: 00014 ### eval_score: 0.31562
# trial: 0075 ### iterations: 00022 ### eval_score: 0.325
# trial: 0076 ### iterations: 00016 ### eval_score: 0.31875
# trial: 0077 ### iterations: 00019 ### eval_score: 0.30938
# trial: 0078 ### iterations: 00016 ### eval_score: 0.3
# trial: 0079 ### iterations: 00012 ### eval_score: 0.33125
# trial: 0080 ### iterations: 00013 ### eval_score: 0.33125
# trial: 0081 ### iterations: 00023 ### eval_score: 0.32188
# trial: 0082 ### iterations: 00013 ### eval_score: 0.33437
# trial: 0083 ### iterations: 00014 ### eval_score: 0.35625
# trial: 0084 ### iterations: 00012 ### eval_score: 0.3625
# trial: 0085 ### iterations: 00015 ### eval_score: 0.31562
# trial: 0086 ### iterations: 00014 ### eval_score: 0.3
# trial: 0087 ### iterations: 00023 ### eval_score: 0.33437
# trial: 0088 ### iterations: 00013 ### eval_score: 0.35938
# trial: 0089 ### iterations: 00012 ### eval_score: 0.3
# trial: 0090 ### iterations: 00020 ### eval_score: 0.32188
# trial: 0091 ### iterations: 00024 ### eval_score: 0.30625
# trial: 0092 ### iterations: 00022 ### eval_score: 0.33125
# trial: 0093 ### iterations: 00013 ### eval_score: 0.30938
# trial: 0094 ### iterations: 00014 ### eval_score: 0.32812
# trial: 0095 ### iterations: 00012 ### eval_score: 0.33125
# trial: 0096 ### iterations: 00016 ### eval_score: 0.34063
# trial: 0097 ### iterations: 00015 ### eval_score: 0.3375
# trial: 0098 ### iterations: 00014 ### eval_score: 0.33437
# trial: 0099 ### iterations: 00022 ### eval_score: 0.34687
# trial: 0100 ### iterations: 00018 ### eval_score: 0.36562
# trial: 0101 ### iterations: 00024 ### eval_score: 0.29688
# trial: 0102 ### iterations: 00022 ### eval_score: 0.31875
# trial: 0103 ### iterations: 00021 ### eval_score: 0.34687
# trial: 0104 ### iterations: 00015 ### eval_score: 0.34063
# trial: 0105 ### iterations: 00021 ### eval_score: 0.31562
# trial: 0106 ### iterations: 00013 ### eval_score: 0.31562
# trial: 0107 ### iterations: 00022 ### eval_score: 0.32812
# trial: 0108 ### iterations: 00020 ### eval_score: 0.33437
# trial: 0109 ### iterations: 00015 ### eval_score: 0.31875
# trial: 0110 ### iterations: 00013 ### eval_score: 0.33125
# trial: 0111 ### iterations: 00020 ### eval_score: 0.33437
# trial: 0112 ### iterations: 00014 ### eval_score: 0.34063
# trial: 0113 ### iterations: 00023 ### eval_score: 0.33125
# trial: 0114 ### iterations: 00015 ### eval_score: 0.32812
# trial: 0115 ### iterations: 00024 ### eval_score: 0.34375
# trial: 0116 ### iterations: 00022 ### eval_score: 0.35625
# trial: 0117 ### iterations: 00024 ### eval_score: 0.3125
# trial: 0118 ### iterations: 00019 ### eval_score: 0.34687
# trial: 0119 ### iterations: 00019 ### eval_score: 0.35625
# trial: 0120 ### iterations: 00015 ### eval_score: 0.35313
# trial: 0121 ### iterations: 00011 ### eval_score: 0.30938
# trial: 0122 ### iterations: 00010 ### eval_score: 0.3375
# trial: 0123 ### iterations: 00024 ### eval_score: 0.32812
# trial: 0124 ### iterations: 00024 ### eval_score: 0.34063
# trial: 0125 ### iterations: 00015 ### eval_score: 0.30312
# trial: 0126 ### iterations: 00019 ### eval_score: 0.32188
# trial: 0127 ### iterations: 00013 ### eval_score: 0.325
# trial: 0128 ### iterations: 00020 ### eval_score: 0.3375
# trial: 0129 ### iterations: 00016 ### eval_score: 0.32188
# trial: 0130 ### iterations: 00024 ### eval_score: 0.32188
# trial: 0131 ### iterations: 00020 ### eval_score: 0.37812
# trial: 0132 ### iterations: 00002 ### eval_score: 0.39375
# trial: 0133 ### iterations: 00032 ### eval_score: 0.33437
# trial: 0134 ### iterations: 00024 ### eval_score: 0.34063
# trial: 0135 ### iterations: 00002 ### eval_score: 0.3625
# trial: 0136 ### iterations: 00007 ### eval_score: 0.3625
# trial: 0137 ### iterations: 00015 ### eval_score: 0.31562
# trial: 0138 ### iterations: 00010 ### eval_score: 0.32188
# trial: 0139 ### iterations: 00014 ### eval_score: 0.3875
# trial: 0140 ### iterations: 00004 ### eval_score: 0.38125
# trial: 0141 ### iterations: 00001 ### eval_score: 0.3125
# trial: 0142 ### iterations: 00001 ### eval_score: 0.31562
# trial: 0143 ### iterations: 00000 ### eval_score: 0.3875
# trial: 0144 ### iterations: 00000 ### eval_score: 0.38125
# trial: 0145 ### iterations: 00006 ### eval_score: 0.35625
# trial: 0146 ### iterations: 00008 ### eval_score: 0.35625
# trial: 0147 ### iterations: 00016 ### eval_score: 0.38438
# trial: 0148 ### iterations: 00007 ### eval_score: 0.4
# trial: 0149 ### iterations: 00002 ### eval_score: 0.35313
# trial: 0150 ### iterations: 00002 ### eval_score: 0.35313
# trial: 0151 ### iterations: 00002 ### eval_score: 0.36875
# trial: 0152 ### iterations: 00002 ### eval_score: 0.3625
# trial: 0153 ### iterations: 00001 ### eval_score: 0.35938
# trial: 0154 ### iterations: 00035 ### eval_score: 0.32812
# trial: 0155 ### iterations: 00011 ### eval_score: 0.38438
# trial: 0156 ### iterations: 00009 ### eval_score: 0.38438
# trial: 0157 ### iterations: 00003 ### eval_score: 0.35
# trial: 0158 ### iterations: 00003 ### eval_score: 0.35
# trial: 0159 ### iterations: 00000 ### eval_score: 0.39062
# trial: 0160 ### iterations: 00000 ### eval_score: 0.39375
# trial: 0161 ### iterations: 00005 ### eval_score: 0.34687
# trial: 0162 ### iterations: 00013 ### eval_score: 0.35625
# trial: 0163 ### iterations: 00002 ### eval_score: 0.39062
# trial: 0164 ### iterations: 00001 ### eval_score: 0.39062
# trial: 0165 ### iterations: 00010 ### eval_score: 0.35
# trial: 0166 ### iterations: 00008 ### eval_score: 0.35625
# trial: 0167 ### iterations: 00002 ### eval_score: 0.36562
# trial: 0168 ### iterations: 00002 ### eval_score: 0.36562
# trial: 0169 ### iterations: 00016 ### eval_score: 0.3375
# trial: 0170 ### iterations: 00023 ### eval_score: 0.3375
# trial: 0171 ### iterations: 00016 ### eval_score: 0.39062
# trial: 0172 ### iterations: 00020 ### eval_score: 0.37812
# trial: 0173 ### iterations: 00003 ### eval_score: 0.34375
# trial: 0174 ### iterations: 00003 ### eval_score: 0.35
# trial: 0175 ### iterations: 00000 ### eval_score: 0.39375
# trial: 0176 ### iterations: 00000 ### eval_score: 0.39375
# trial: 0177 ### iterations: 00011 ### eval_score: 0.375
# trial: 0178 ### iterations: 00023 ### eval_score: 0.36562
# trial: 0179 ### iterations: 00001 ### eval_score: 0.3875
# trial: 0180 ### iterations: 00009 ### eval_score: 0.39375
# trial: 0181 ### iterations: 00001 ### eval_score: 0.36562
# trial: 0182 ### iterations: 00001 ### eval_score: 0.36562
# trial: 0183 ### iterations: 00002 ### eval_score: 0.38125
# trial: 0184 ### iterations: 00002 ### eval_score: 0.37812
# trial: 0185 ### iterations: 00001 ### eval_score: 0.36875
# trial: 0186 ### iterations: 00011 ### eval_score: 0.34063
# trial: 0187 ### iterations: 00008 ### eval_score: 0.38125
# trial: 0188 ### iterations: 00005 ### eval_score: 0.375
# trial: 0189 ### iterations: 00008 ### eval_score: 0.35938
# trial: 0190 ### iterations: 00009 ### eval_score: 0.35625
# trial: 0191 ### iterations: 00014 ### eval_score: 0.3875
# trial: 0192 ### iterations: 00012 ### eval_score: 0.39062
# trial: 0193 ### iterations: 00016 ### eval_score: 0.32188
# trial: 0194 ### iterations: 00024 ### eval_score: 0.32188
# trial: 0195 ### iterations: 00020 ### eval_score: 0.37812
# trial: 0196 ### iterations: 00002 ### eval_score: 0.39375
# trial: 0197 ### iterations: 00024 ### eval_score: 0.34375
# trial: 0198 ### iterations: 00024 ### eval_score: 0.34063
# trial: 0199 ### iterations: 00002 ### eval_score: 0.3625
# trial: 0200 ### iterations: 00007 ### eval_score: 0.3625
# trial: 0201 ### iterations: 00015 ### eval_score: 0.31562
# trial: 0202 ### iterations: 00010 ### eval_score: 0.32188
# trial: 0203 ### iterations: 00014 ### eval_score: 0.3875
# trial: 0204 ### iterations: 00004 ### eval_score: 0.38125
# trial: 0205 ### iterations: 00001 ### eval_score: 0.3125
# trial: 0206 ### iterations: 00001 ### eval_score: 0.31562
# trial: 0207 ### iterations: 00000 ### eval_score: 0.3875
# trial: 0208 ### iterations: 00000 ### eval_score: 0.38125
# trial: 0209 ### iterations: 00006 ### eval_score: 0.35625
# trial: 0210 ### iterations: 00008 ### eval_score: 0.35625
# trial: 0211 ### iterations: 00016 ### eval_score: 0.38438
# trial: 0212 ### iterations: 00007 ### eval_score: 0.4
# trial: 0213 ### iterations: 00002 ### eval_score: 0.35313
# trial: 0214 ### iterations: 00002 ### eval_score: 0.35313
# trial: 0215 ### iterations: 00002 ### eval_score: 0.36875
# trial: 0216 ### iterations: 00002 ### eval_score: 0.3625
# trial: 0217 ### iterations: 00001 ### eval_score: 0.35938
# trial: 0218 ### iterations: 00018 ### eval_score: 0.32812
# trial: 0219 ### iterations: 00011 ### eval_score: 0.38438
# trial: 0220 ### iterations: 00009 ### eval_score: 0.38438
# trial: 0221 ### iterations: 00003 ### eval_score: 0.35
# trial: 0222 ### iterations: 00003 ### eval_score: 0.35
# trial: 0223 ### iterations: 00000 ### eval_score: 0.39062
# trial: 0224 ### iterations: 00000 ### eval_score: 0.39375
# trial: 0225 ### iterations: 00005 ### eval_score: 0.34687
# trial: 0226 ### iterations: 00013 ### eval_score: 0.35625
# trial: 0227 ### iterations: 00002 ### eval_score: 0.39062
# trial: 0228 ### iterations: 00001 ### eval_score: 0.39062
# trial: 0229 ### iterations: 00010 ### eval_score: 0.35
# trial: 0230 ### iterations: 00008 ### eval_score: 0.35625
# trial: 0231 ### iterations: 00002 ### eval_score: 0.36562
# trial: 0232 ### iterations: 00002 ### eval_score: 0.36562
# trial: 0233 ### iterations: 00016 ### eval_score: 0.3375
# trial: 0234 ### iterations: 00023 ### eval_score: 0.3375
# trial: 0235 ### iterations: 00016 ### eval_score: 0.39062
# trial: 0236 ### iterations: 00020 ### eval_score: 0.37812
# trial: 0237 ### iterations: 00003 ### eval_score: 0.34375
# trial: 0238 ### iterations: 00003 ### eval_score: 0.35
# trial: 0239 ### iterations: 00000 ### eval_score: 0.39375
# trial: 0240 ### iterations: 00000 ### eval_score: 0.39375
# trial: 0241 ### iterations: 00011 ### eval_score: 0.375
# trial: 0242 ### iterations: 00023 ### eval_score: 0.36562
# trial: 0243 ### iterations: 00001 ### eval_score: 0.3875
# trial: 0244 ### iterations: 00009 ### eval_score: 0.39375
# trial: 0245 ### iterations: 00001 ### eval_score: 0.36562
# trial: 0246 ### iterations: 00001 ### eval_score: 0.36562
# trial: 0247 ### iterations: 00002 ### eval_score: 0.38125
# trial: 0248 ### iterations: 00002 ### eval_score: 0.37812
# trial: 0249 ### iterations: 00001 ### eval_score: 0.36875
# trial: 0250 ### iterations: 00011 ### eval_score: 0.34063
# trial: 0251 ### iterations: 00008 ### eval_score: 0.38125
# trial: 0252 ### iterations: 00005 ### eval_score: 0.375
# trial: 0253 ### iterations: 00008 ### eval_score: 0.35938
# trial: 0254 ### iterations: 00009 ### eval_score: 0.35625
# trial: 0255 ### iterations: 00014 ### eval_score: 0.3875
# trial: 0256 ### iterations: 00012 ### eval_score: 0.39062
# trial: 0257 ### iterations: 00020 ### eval_score: 0.33437
# trial: 0258 ### iterations: 00022 ### eval_score: 0.33125
# trial: 0259 ### iterations: 00038 ### eval_score: 0.35
# trial: 0260 ### iterations: 00018 ### eval_score: 0.36562
# trial: 0261 ### iterations: 00021 ### eval_score: 0.32812
# trial: 0262 ### iterations: 00023 ### eval_score: 0.35625
# trial: 0263 ### iterations: 00030 ### eval_score: 0.33437
# trial: 0264 ### iterations: 00009 ### eval_score: 0.35
# trial: 0265 ### iterations: 00014 ### eval_score: 0.33125
# trial: 0266 ### iterations: 00029 ### eval_score: 0.325
# trial: 0267 ### iterations: 00028 ### eval_score: 0.33125
# trial: 0268 ### iterations: 00026 ### eval_score: 0.33125
# trial: 0269 ### iterations: 00010 ### eval_score: 0.32812
# trial: 0270 ### iterations: 00013 ### eval_score: 0.33437
# trial: 0271 ### iterations: 00027 ### eval_score: 0.35313
# trial: 0272 ### iterations: 00022 ### eval_score: 0.35313
# trial: 0273 ### iterations: 00017 ### eval_score: 0.34063
# trial: 0274 ### iterations: 00025 ### eval_score: 0.34063
# trial: 0275 ### iterations: 00011 ### eval_score: 0.375
# trial: 0276 ### iterations: 00025 ### eval_score: 0.37188
# trial: 0277 ### iterations: 00008 ### eval_score: 0.34375
# trial: 0278 ### iterations: 00002 ### eval_score: 0.35313
# trial: 0279 ### iterations: 00027 ### eval_score: 0.32812
# trial: 0280 ### iterations: 00011 ### eval_score: 0.35938
# trial: 0281 ### iterations: 00022 ### eval_score: 0.31562
# trial: 0282 ### iterations: 00020 ### eval_score: 0.31875
# trial: 0283 ### iterations: 00025 ### eval_score: 0.3375
# trial: 0284 ### iterations: 00040 ### eval_score: 0.33125
# trial: 0285 ### iterations: 00032 ### eval_score: 0.3125
# trial: 0286 ### iterations: 00016 ### eval_score: 0.33437
# trial: 0287 ### iterations: 00016 ### eval_score: 0.34375
# trial: 0288 ### iterations: 00019 ### eval_score: 0.33437
# trial: 0289 ### iterations: 00037 ### eval_score: 0.325
# trial: 0290 ### iterations: 00014 ### eval_score: 0.34063
# trial: 0291 ### iterations: 00032 ### eval_score: 0.36875
# trial: 0292 ### iterations: 00026 ### eval_score: 0.34687
# trial: 0293 ### iterations: 00015 ### eval_score: 0.35625
# trial: 0294 ### iterations: 00014 ### eval_score: 0.34375
# trial: 0295 ### iterations: 00010 ### eval_score: 0.36562
# trial: 0296 ### iterations: 00028 ### eval_score: 0.34375
# trial: 0297 ### iterations: 00042 ### eval_score: 0.30938
# trial: 0298 ### iterations: 00015 ### eval_score: 0.325
# trial: 0299 ### iterations: 00021 ### eval_score: 0.34375
# trial: 0300 ### iterations: 00031 ### eval_score: 0.34063
# trial: 0301 ### iterations: 00012 ### eval_score: 0.32812
# trial: 0302 ### iterations: 00016 ### eval_score: 0.3375
# trial: 0303 ### iterations: 00027 ### eval_score: 0.33125
# trial: 0304 ### iterations: 00021 ### eval_score: 0.33437
# trial: 0305 ### iterations: 00032 ### eval_score: 0.325
# trial: 0306 ### iterations: 00018 ### eval_score: 0.325
# trial: 0307 ### iterations: 00033 ### eval_score: 0.35625
# trial: 0308 ### iterations: 00009 ### eval_score: 0.36562
# trial: 0309 ### iterations: 00015 ### eval_score: 0.32812
# trial: 0310 ### iterations: 00028 ### eval_score: 0.32812
# trial: 0311 ### iterations: 00022 ### eval_score: 0.35938
# trial: 0312 ### iterations: 00016 ### eval_score: 0.35625
# trial: 0313 ### iterations: 00015 ### eval_score: 0.34687
# trial: 0314 ### iterations: 00007 ### eval_score: 0.34063
# trial: 0315 ### iterations: 00011 ### eval_score: 0.3625
# trial: 0316 ### iterations: 00022 ### eval_score: 0.34375
# trial: 0317 ### iterations: 00020 ### eval_score: 0.31875
# trial: 0318 ### iterations: 00023 ### eval_score: 0.325
# trial: 0319 ### iterations: 00024 ### eval_score: 0.31562
# trial: 0320 ### iterations: 00024 ### eval_score: 0.3375
# trial: 0321 ### iterations: 00020 ### eval_score: 0.33437
# trial: 0322 ### iterations: 00022 ### eval_score: 0.33125
# trial: 0323 ### iterations: 00004 ### eval_score: 0.37188
# trial: 0324 ### iterations: 00018 ### eval_score: 0.36562
# trial: 0325 ### iterations: 00021 ### eval_score: 0.32812
# trial: 0326 ### iterations: 00023 ### eval_score: 0.35625
# trial: 0327 ### iterations: 00020 ### eval_score: 0.34375
# trial: 0328 ### iterations: 00009 ### eval_score: 0.35
# trial: 0329 ### iterations: 00014 ### eval_score: 0.33125
# trial: 0330 ### iterations: 00023 ### eval_score: 0.32812
# trial: 0331 ### iterations: 00019 ### eval_score: 0.34063
# trial: 0332 ### iterations: 00023 ### eval_score: 0.34687
# trial: 0333 ### iterations: 00010 ### eval_score: 0.32812
# trial: 0334 ### iterations: 00013 ### eval_score: 0.33437
# trial: 0335 ### iterations: 00019 ### eval_score: 0.35625
# trial: 0336 ### iterations: 00022 ### eval_score: 0.35313
# trial: 0337 ### iterations: 00017 ### eval_score: 0.34063
# trial: 0338 ### iterations: 00024 ### eval_score: 0.34375
# trial: 0339 ### iterations: 00011 ### eval_score: 0.375
# trial: 0340 ### iterations: 00006 ### eval_score: 0.375
# trial: 0341 ### iterations: 00008 ### eval_score: 0.34375
# trial: 0342 ### iterations: 00002 ### eval_score: 0.35313
# trial: 0343 ### iterations: 00024 ### eval_score: 0.3375
# trial: 0344 ### iterations: 00011 ### eval_score: 0.35938
# trial: 0345 ### iterations: 00022 ### eval_score: 0.31562
# trial: 0346 ### iterations: 00020 ### eval_score: 0.31875
# trial: 0347 ### iterations: 00019 ### eval_score: 0.34375
# trial: 0348 ### iterations: 00023 ### eval_score: 0.35313
# trial: 0349 ### iterations: 00016 ### eval_score: 0.31875
# trial: 0350 ### iterations: 00016 ### eval_score: 0.33437
# trial: 0351 ### iterations: 00016 ### eval_score: 0.34375
# trial: 0352 ### iterations: 00019 ### eval_score: 0.33437
# trial: 0353 ### iterations: 00020 ### eval_score: 0.325
# trial: 0354 ### iterations: 00014 ### eval_score: 0.34063
# trial: 0355 ### iterations: 00021 ### eval_score: 0.375
# trial: 0356 ### iterations: 00020 ### eval_score: 0.35938
# trial: 0357 ### iterations: 00015 ### eval_score: 0.35625
# trial: 0358 ### iterations: 00014 ### eval_score: 0.34375
# trial: 0359 ### iterations: 00010 ### eval_score: 0.36562
# trial: 0360 ### iterations: 00023 ### eval_score: 0.34687
# trial: 0361 ### iterations: 00024 ### eval_score: 0.31562
# trial: 0362 ### iterations: 00015 ### eval_score: 0.325
# trial: 0363 ### iterations: 00021 ### eval_score: 0.34375
# trial: 0364 ### iterations: 00021 ### eval_score: 0.35625
# trial: 0365 ### iterations: 00023 ### eval_score: 0.3375
# trial: 0366 ### iterations: 00016 ### eval_score: 0.3375
# trial: 0367 ### iterations: 00021 ### eval_score: 0.34063
# trial: 0368 ### iterations: 00021 ### eval_score: 0.33437
# trial: 0369 ### iterations: 00008 ### eval_score: 0.3375
# trial: 0370 ### iterations: 00018 ### eval_score: 0.325
# trial: 0371 ### iterations: 00018 ### eval_score: 0.36562
# trial: 0372 ### iterations: 00009 ### eval_score: 0.36562
# trial: 0373 ### iterations: 00015 ### eval_score: 0.32812
# trial: 0374 ### iterations: 00021 ### eval_score: 0.34063
# trial: 0375 ### iterations: 00022 ### eval_score: 0.35938
# trial: 0376 ### iterations: 00016 ### eval_score: 0.35625
# trial: 0377 ### iterations: 00015 ### eval_score: 0.34687
# trial: 0378 ### iterations: 00007 ### eval_score: 0.34063
# trial: 0379 ### iterations: 00011 ### eval_score: 0.3625
# trial: 0380 ### iterations: 00022 ### eval_score: 0.34375
# trial: 0381 ### iterations: 00020 ### eval_score: 0.31875
# trial: 0382 ### iterations: 00023 ### eval_score: 0.325
# trial: 0383 ### iterations: 00024 ### eval_score: 0.31562
# trial: 0384 ### iterations: 00024 ### eval_score: 0.3375
# trial: 0385 ### iterations: 00015 ### eval_score: 0.36562
# trial: 0386 ### iterations: 00015 ### eval_score: 0.35938
# trial: 0387 ### iterations: 00003 ### eval_score: 0.3875
# trial: 0388 ### iterations: 00004 ### eval_score: 0.39062
# trial: 0389 ### iterations: 00012 ### eval_score: 0.36562
# trial: 0390 ### iterations: 00012 ### eval_score: 0.36562
# trial: 0391 ### iterations: 00002 ### eval_score: 0.36875
# trial: 0392 ### iterations: 00001 ### eval_score: 0.36875
# trial: 0393 ### iterations: 00013 ### eval_score: 0.36562
# trial: 0394 ### iterations: 00019 ### eval_score: 0.34375
# trial: 0395 ### iterations: 00023 ### eval_score: 0.3875
# trial: 0396 ### iterations: 00018 ### eval_score: 0.3875
# trial: 0397 ### iterations: 00001 ### eval_score: 0.3625
# trial: 0398 ### iterations: 00001 ### eval_score: 0.3625
# trial: 0399 ### iterations: 00002 ### eval_score: 0.375
# trial: 0400 ### iterations: 00002 ### eval_score: 0.375
# trial: 0401 ### iterations: 00006 ### eval_score: 0.37812
# trial: 0402 ### iterations: 00025 ### eval_score: 0.375
# trial: 0403 ### iterations: 00008 ### eval_score: 0.38438
# trial: 0404 ### iterations: 00002 ### eval_score: 0.39375
# trial: 0405 ### iterations: 00009 ### eval_score: 0.36562
# trial: 0406 ### iterations: 00005 ### eval_score: 0.36875
# trial: 0407 ### iterations: 00013 ### eval_score: 0.37188
# trial: 0408 ### iterations: 00003 ### eval_score: 0.36875
# trial: 0409 ### iterations: 00012 ### eval_score: 0.36562
# trial: 0410 ### iterations: 00015 ### eval_score: 0.36562
# trial: 0411 ### iterations: 00019 ### eval_score: 0.38438
# trial: 0412 ### iterations: 00019 ### eval_score: 0.3875
# trial: 0413 ### iterations: 00000 ### eval_score: 0.38125
# trial: 0414 ### iterations: 00000 ### eval_score: 0.37812
# trial: 0415 ### iterations: 00003 ### eval_score: 0.38438
# trial: 0416 ### iterations: 00003 ### eval_score: 0.3875
# trial: 0417 ### iterations: 00004 ### eval_score: 0.37812
# trial: 0418 ### iterations: 00010 ### eval_score: 0.37812
# trial: 0419 ### iterations: 00002 ### eval_score: 0.39062
# trial: 0420 ### iterations: 00002 ### eval_score: 0.3875
# trial: 0421 ### iterations: 00011 ### eval_score: 0.36875
# trial: 0422 ### iterations: 00001 ### eval_score: 0.36562
# trial: 0423 ### iterations: 00001 ### eval_score: 0.375
# trial: 0424 ### iterations: 00010 ### eval_score: 0.375
# trial: 0425 ### iterations: 00015 ### eval_score: 0.36562
# trial: 0426 ### iterations: 00004 ### eval_score: 0.375
# trial: 0427 ### iterations: 00010 ### eval_score: 0.38438
# trial: 0428 ### iterations: 00008 ### eval_score: 0.38438
# trial: 0429 ### iterations: 00010 ### eval_score: 0.3875
# trial: 0430 ### iterations: 00009 ### eval_score: 0.3875
# trial: 0431 ### iterations: 00001 ### eval_score: 0.4
# trial: 0432 ### iterations: 00001 ### eval_score: 0.4
# trial: 0433 ### iterations: 00009 ### eval_score: 0.38438
# trial: 0434 ### iterations: 00008 ### eval_score: 0.38438
# trial: 0435 ### iterations: 00003 ### eval_score: 0.39375
# trial: 0436 ### iterations: 00004 ### eval_score: 0.39687
# trial: 0437 ### iterations: 00010 ### eval_score: 0.3625
# trial: 0438 ### iterations: 00010 ### eval_score: 0.35938
# trial: 0439 ### iterations: 00001 ### eval_score: 0.37812
# trial: 0440 ### iterations: 00006 ### eval_score: 0.37812
# trial: 0441 ### iterations: 00011 ### eval_score: 0.40313
# trial: 0442 ### iterations: 00014 ### eval_score: 0.37812
# trial: 0443 ### iterations: 00014 ### eval_score: 0.38438
# trial: 0444 ### iterations: 00010 ### eval_score: 0.38438
# trial: 0445 ### iterations: 00016 ### eval_score: 0.38125
# trial: 0446 ### iterations: 00010 ### eval_score: 0.38438
# trial: 0447 ### iterations: 00001 ### eval_score: 0.39687
# trial: 0448 ### iterations: 00001 ### eval_score: 0.4
# trial: 0449 ### iterations: 00015 ### eval_score: 0.36562
# trial: 0450 ### iterations: 00015 ### eval_score: 0.35938
# trial: 0451 ### iterations: 00003 ### eval_score: 0.3875
# trial: 0452 ### iterations: 00004 ### eval_score: 0.39062
# trial: 0453 ### iterations: 00012 ### eval_score: 0.36562
# trial: 0454 ### iterations: 00012 ### eval_score: 0.36562
# trial: 0455 ### iterations: 00002 ### eval_score: 0.36875
# trial: 0456 ### iterations: 00001 ### eval_score: 0.36875
# trial: 0457 ### iterations: 00013 ### eval_score: 0.36562
# trial: 0458 ### iterations: 00019 ### eval_score: 0.34375
# trial: 0459 ### iterations: 00023 ### eval_score: 0.3875
# trial: 0460 ### iterations: 00018 ### eval_score: 0.3875
# trial: 0461 ### iterations: 00001 ### eval_score: 0.3625
# trial: 0462 ### iterations: 00001 ### eval_score: 0.3625
# trial: 0463 ### iterations: 00002 ### eval_score: 0.375
# trial: 0464 ### iterations: 00002 ### eval_score: 0.375
# trial: 0465 ### iterations: 00006 ### eval_score: 0.37812
# trial: 0466 ### iterations: 00007 ### eval_score: 0.37812
# trial: 0467 ### iterations: 00008 ### eval_score: 0.38438
# trial: 0468 ### iterations: 00002 ### eval_score: 0.39375
# trial: 0469 ### iterations: 00009 ### eval_score: 0.36562
# trial: 0470 ### iterations: 00005 ### eval_score: 0.36875
# trial: 0471 ### iterations: 00013 ### eval_score: 0.37188
# trial: 0472 ### iterations: 00003 ### eval_score: 0.36875
# trial: 0473 ### iterations: 00012 ### eval_score: 0.36562
# trial: 0474 ### iterations: 00015 ### eval_score: 0.36562
# trial: 0475 ### iterations: 00019 ### eval_score: 0.38438
# trial: 0476 ### iterations: 00019 ### eval_score: 0.3875
# trial: 0477 ### iterations: 00000 ### eval_score: 0.38125
# trial: 0478 ### iterations: 00000 ### eval_score: 0.37812
# trial: 0479 ### iterations: 00003 ### eval_score: 0.38438
# trial: 0480 ### iterations: 00003 ### eval_score: 0.3875
# trial: 0481 ### iterations: 00004 ### eval_score: 0.37812
# trial: 0482 ### iterations: 00010 ### eval_score: 0.37812
# trial: 0483 ### iterations: 00002 ### eval_score: 0.39062
# trial: 0484 ### iterations: 00002 ### eval_score: 0.3875
# trial: 0485 ### iterations: 00011 ### eval_score: 0.36875
# trial: 0486 ### iterations: 00001 ### eval_score: 0.36562
# trial: 0487 ### iterations: 00001 ### eval_score: 0.375
# trial: 0488 ### iterations: 00010 ### eval_score: 0.375
# trial: 0489 ### iterations: 00015 ### eval_score: 0.36562
# trial: 0490 ### iterations: 00004 ### eval_score: 0.375
# trial: 0491 ### iterations: 00010 ### eval_score: 0.38438
# trial: 0492 ### iterations: 00008 ### eval_score: 0.38438
# trial: 0493 ### iterations: 00010 ### eval_score: 0.3875
# trial: 0494 ### iterations: 00009 ### eval_score: 0.3875
# trial: 0495 ### iterations: 00001 ### eval_score: 0.4
# trial: 0496 ### iterations: 00001 ### eval_score: 0.4
# trial: 0497 ### iterations: 00009 ### eval_score: 0.38438
# trial: 0498 ### iterations: 00008 ### eval_score: 0.38438
# trial: 0499 ### iterations: 00003 ### eval_score: 0.39375
# trial: 0500 ### iterations: 00004 ### eval_score: 0.39687
# trial: 0501 ### iterations: 00010 ### eval_score: 0.3625
# trial: 0502 ### iterations: 00010 ### eval_score: 0.35938
# trial: 0503 ### iterations: 00001 ### eval_score: 0.37812
# trial: 0504 ### iterations: 00006 ### eval_score: 0.37812
# trial: 0505 ### iterations: 00011 ### eval_score: 0.40313
# trial: 0506 ### iterations: 00014 ### eval_score: 0.37812
# trial: 0507 ### iterations: 00014 ### eval_score: 0.38438
# trial: 0508 ### iterations: 00010 ### eval_score: 0.38438
# trial: 0509 ### iterations: 00016 ### eval_score: 0.38125
# trial: 0510 ### iterations: 00010 ### eval_score: 0.38438
# trial: 0511 ### iterations: 00001 ### eval_score: 0.39687
# trial: 0512 ### iterations: 00001 ### eval_score: 0.4

# %%
test_eval(xclf, X_test, y_test, 'XGB')
# Out:
# Confusion Matrix
# ============================================================
# [[  0   0   2   0   0   0]
#  [  0   1   9   1   0   0]
#  [  0   3 110  22   1   0]
#  [  0   0  30  91   7   0]
#  [  0   0   1  16  23   0]
#  [  0   0   0   1   2   0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.25      0.09      0.13        11
#            5       0.72      0.81      0.76       136
#            6       0.69      0.71      0.70       128
#            7       0.70      0.57      0.63        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.70       320
#    macro avg       0.39      0.36      0.37       320
# weighted avg       0.68      0.70      0.69       320
#
#
# ============================================================
# AUC-ROC
# 0.8078887198012291
#
# Balanced Accuracy
# 0.36427835338680925
#
# Geometric Mean Score
# 0.5788036049697353
#
# Sensitivity
# 0.36427835338680925
#
# Specificity
# 0.9196637955871809

# %% [markdown]
# # MODEL-7 Stacking

# %%
clf_DT = DecisionTreeClassifier()
clf_SVC = SVC(probability=True)
clf_KNN = KNeighborsClassifier()
clf_LR = LogisticRegression()

sclf = StackingClassifier(classifiers=[clf_DT, clf_SVC, clf_KNN], use_probas=True, average_probas=False, meta_classifier=clf_LR)

# %%
sclf.fit(X_train, y_train)
test_eval(sclf, X_test, y_test, 'Stacking')
# Out:
# Confusion Matrix
# ============================================================
# [[  0   1   1   0   0   0]
#  [  0   2   6   2   1   0]
#  [  0   6 100  28   2   0]
#  [  0   8  30  74  16   0]
#  [  0   3   7  12  17   1]
#  [  0   0   0   2   1   0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.10      0.18      0.13        11
#            5       0.69      0.74      0.71       136
#            6       0.63      0.58      0.60       128
#            7       0.46      0.42      0.44        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.60       320
#    macro avg       0.31      0.32      0.31       320
# weighted avg       0.61      0.60      0.60       320
#
#
# ============================================================
# AUC-ROC
# 0.79329669278576
#
# Balanced Accuracy
# 0.32003954991087347
#
# Geometric Mean Score
# 0.5366331877206278
#
# Sensitivity
# 0.32003954991087347
#
# Specificity
# 0.8998112209675325

# %% [markdown]
# # MODEL-8 Bagging

# %%
clf_bg = BaggingClassifier(clf_DT)

# %%
clf_bg.fit(X_train, y_train)
test_eval(clf_bg, X_test, y_test, 'Bagging')
# Out:
# Confusion Matrix
# ============================================================
# [[  0   0   2   0   0   0]
#  [  0   0   8   3   0   0]
#  [  0   1 107  27   1   0]
#  [  0   2  41  78   7   0]
#  [  0   1   3  16  19   1]
#  [  0   0   0   1   2   0]]
#
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         2
#            4       0.00      0.00      0.00        11
#            5       0.66      0.79      0.72       136
#            6       0.62      0.61      0.62       128
#            7       0.66      0.47      0.55        40
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.64       320
#    macro avg       0.32      0.31      0.31       320
# weighted avg       0.61      0.64      0.62       320
#
#
# ============================================================
# AUC-ROC
# 0.6963390346563427
#
# Balanced Accuracy
# 0.3118566176470588
#
# Geometric Mean Score
# 0.5302700847786508
#
# Sensitivity
# 0.3118566176470588
#
# Specificity
# 0.9016527047997034

# %%
clf_eval_df = pd.DataFrame({'model':model,
                            'precision':precision,
                            'recall':recall,
                            'f1-score':F1score,
                            'AUC-ROC':AUCROC,
                            'balanced_acc':balanced_acc,
                            'GMean':GMean,
                            'sensitivity':sensi,
                            'specificity':speci})
clf_eval_df
# Out:
#                  model  precision    recall  f1-score   AUC-ROC  balanced_acc  \
# 0  Logistic Regression   0.279657  0.261366  0.255675  0.818144      0.261366
# 1        Decision Tree   0.314243  0.326259  0.317626  0.612604      0.326259
# 2          Gaussian NB   0.338673  0.370448  0.345178  0.702528      0.370448
# 3                  KNN   0.397243  0.301795  0.323508  0.631795      0.301795
# 4                  SVC   0.308107  0.281725  0.284619  0.831109      0.281725
# 5                  XGB   0.394218  0.364278  0.371677  0.807889      0.364278
# 6             Stacking   0.313504  0.320040  0.314417  0.793297      0.320040
# 7              Bagging   0.323961  0.311857  0.314644  0.696339      0.311857
#
#       GMean  sensitivity  specificity
# 0  0.482376     0.261366     0.890270
# 1  0.541563     0.326259     0.898949
# 2  0.575142     0.370448     0.892941
# 3  0.513725     0.301795     0.874478
# 4  0.500800     0.281725     0.890232
# 5  0.578804     0.364278     0.919664
# 6  0.536633     0.320040     0.899811
# 7  0.530270     0.311857     0.901653

# %%
clf_eval_df.to_excel("D:\Skripsi\Final\project_redwine_final.xlsx")
